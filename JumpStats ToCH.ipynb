# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# input data from Roblox console

CCOString = [[ 3.96, 8.65, 10.71, 0.06, 0.01, 0.02, 0.52 ],[ 7.78, 8.60, 12.61, 0.03, 0.01, 0.00, 0.53 ],[ 8.07, 9.84, 13.59, 0.02, 0.02, 0.00, 0.57 ],[ 5.55, 7.79, 10.10, 0.46, 0.00, 0.25, 0.47 ],[ 5.03, 7.23, 9.53, 0.40, 0.00, 0.20, 0.38 ],[ 5.94, 7.77, 10.78, 0.08, 0.00, 0.04, 0.45 ],[ 4.21, 7.31, 9.95, 0.13, 0.00, 0.06, 0.37 ],[ 4.00, 7.25, 9.49, 0.19, 0.00, 0.10, 0.37 ],[ 4.94, 7.47, 9.62, 0.06, 0.01, 0.03, 0.38 ],[ 4.25, 7.26, 9.40, 0.04, 0.00, 0.02, 0.37 ],[ 5.04, 7.30, 9.61, 0.17, 0.00, 0.08, 0.38 ],[ 11.54, 11.22, 19.41, 0.17, 0.00, 0.08, 0.38 ],[ 4.28, 8.10, 10.20, 0.00, 0.01, 0.00, 0.53 ],[ 4.51, 7.21, 9.11, 0.18, 0.00, 0.12, 0.40 ],[ 2.48, 5.29, 6.29, 0.08, 0.00, 0.05, 0.22 ],[ 2.34, 4.47, 5.38, 0.15, 0.00, 0.09, 0.23 ],[ 10.76, 9.65, 15.69, 0.08, 0.00, 0.02, 0.53 ],[ 6.77, 8.64, 11.74, 0.16, 0.00, 0.03, 0.53 ],[ 8.50, 9.47, 13.83, 0.08, 0.00, 0.01, 0.53 ],[ 8.17, 9.33, 13.80, 0.02, 0.00, 0.00, 0.55 ],[ 7.67, 8.61, 12.90, 0.01, 0.00, 0.00, 0.50 ],[ 6.75, 8.63, 11.71, 0.07, 0.00, 0.02, 0.53 ],[ 8.55, 10.35, 14.54, 0.00, 0.01, 0.00, 0.52 ],[ 8.45, 10.01, 14.15, 0.00, 0.02, 0.00, 0.58 ],[ 8.11, 8.68, 13.19, 0.02, 0.00, 0.00, 0.53 ],[ 7.04, 8.62, 11.99, 0.00, 0.00, 0.00, 0.53 ],[ 8.02, 9.03, 13.14, 0.00, 0.00, 0.00, 0.55 ],[ 7.14, 8.69, 12.15, 0.00, 0.00, 0.00, 0.53 ],[ 7.12, 8.61, 12.09, 0.02, 0.00, 0.00, 0.52 ],[ 1.80, 8.33, 9.23, 0.01, 0.00, 0.00, 0.53 ],[ 1.15, 8.79, 9.08, 0.02, 0.01, 0.01, 0.52 ],[ 2.57, 7.53, 8.69, 0.08, 0.00, 0.13, 0.38 ]]
PuristString = [[ 1.58, 8.50, 9.38, 0.03, 0.00, 0.05, 0.52 ], [ 2.43, 7.49, 9.17, 0.01, 0.00, 0.00, 0.47 ], [ 1.09, 7.42, 8.15, 0.00, 0.00, 0.00, 0.43 ], [ 2.30, 7.50, 8.86, 0.01, 0.01, 0.00, 0.40 ], [ 2.80, 8.01, 9.66, 0.02, 0.01, 0.01, 0.45 ], [ 8.73, 10.51, 14.73, 0.01, 0.00, 0.01, 0.55 ], [ 2.98, 7.89, 9.46, 0.01, 0.00, 0.00, 0.45 ], [ 2.05, 7.52, 8.45, 0.01, 0.00, 0.00, 0.38 ], [ 0.75, 6.92, 7.08, 0.01, 0.00, 0.00, 0.33 ], [ 2.89, 7.52, 8.85, 0.01, 0.00, 0.00, 0.38 ], [ 7.15, 9.39, 12.49, 0.01, 0.01, 0.01, 0.53 ], [ 2.44, 7.77, 9.21, 0.02, 0.00, 0.01, 0.47 ], [ 8.03, 9.40, 13.40, 0.44, 0.01, 0.09, 0.53 ], [ 3.65, 8.04, 9.95, 0.99, 0.00, 0.19, 0.47 ], [ 0.04, 5.97, 5.97, 0.01, 0.00, 0.00, 0.23 ], [ 5.89, 7.97, 10.44, 0.02, 0.00, 0.01, 0.47 ], [ 0.90, 7.70, 8.29, 0.18, 0.00, 0.04, 0.47 ], [ 3.93, 9.04, 11.39, 0.05, 0.00, 0.01, 0.53 ], [ 4.16, 8.60, 10.70, 0.01, 0.00, 0.00, 0.53 ], [ 4.82, 10.48, 12.76, 0.01, 0.00, 0.00, 0.53 ], [ 3.66, 9.44, 11.34, 0.00, 0.00, 0.00, 0.52 ], [ 4.88, 8.55, 10.82, 0.00, 0.00, 0.00, 0.47 ], [ 3.16, 10.57, 12.02, 0.05, 0.00, 0.01, 0.60 ], [ 5.30, 10.65, 12.99, 0.31, 0.00, 0.05, 0.55 ], [ 2.60, 7.73, 9.21, 0.09, 0.00, 0.03, 0.47 ], [ 2.32, 7.64, 9.03, 0.01, 0.01, 0.00, 0.45 ], [ 2.62, 8.38, 9.91, 0.01, 0.01, 0.00, 0.52 ], [ 3.33, 9.30, 11.08, 0.03, 0.00, 0.00, 0.52 ], [ 4.00, 8.97, 11.09, 0.01, 0.00, 0.00, 0.52 ], [ 3.32, 7.59, 8.94, 0.05, 0.00, 0.02, 0.45 ], [ 3.74, 7.62, 9.00, 0.12, 0.01, 0.37, 1.03 ], [ 6.43, 8.31, 11.41, 0.55, 0.00, 0.39, 0.47 ], [ 3.84, 5.78, 7.74, 2.46, 0.02, 3.34, 5.00 ], [ 13.29, 16.93, 24.83, 2.50, 0.01, 2.47, 3.68 ], [ 3.04, 9.76, 11.32, 0.08, 0.01, 0.02, 0.52 ], [ 9.71, 15.16, 18.91, 0.02, 0.00, 0.01, 0.68 ], [ 3.81, 9.07, 11.07, 0.07, 0.00, 0.04, 0.53 ], [ 4.74, 9.59, 11.89, 0.00, 0.00, 0.00, 0.52 ], [ 4.48, 9.57, 11.79, 0.00, 0.00, 0.00, 0.52 ], [ 3.94, 3.77, 5.92, 0.00, 0.00, 0.00, 0.25 ], [ 4.77, 8.27, 10.51, 0.00, 0.00, 0.00, 0.47 ], [ 3.29, 7.81, 9.55, 0.05, 0.00, 0.03, 0.45 ], [ 3.76, 8.49, 10.50, 0.00, 0.00, 0.00, 0.50 ], [ 6.21, 9.04, 11.61, 0.02, 0.00, 0.00, 0.52 ], [ 3.55, 8.13, 10.03, 0.02, 0.00, 0.04, 0.47 ], [ 3.52, 8.37, 10.26, 0.00, 0.00, 0.01, 0.52 ], [ 4.16, 8.01, 10.05, 0.00, 0.00, 0.01, 0.43 ], [ 4.39, 8.51, 10.69, 0.02, 0.00, 0.08, 0.48 ], [ 2.29, 7.64, 9.01, 0.02, 0.00, 0.08, 0.40 ], [ 5.69, 9.91, 12.43, 0.06, 0.00, 0.01, 0.58 ], [ 5.87, 8.97, 11.97, 0.01, 0.00, 0.00, 0.53 ], [ 3.05, 8.54, 10.25, 0.00, 0.00, 0.00, 0.52 ], [ 1.97, 7.47, 8.07, 0.00, 0.00, 0.00, 0.38 ], [ 6.14, 8.61, 11.19, 0.00, 0.00, 0.00, 0.52 ], [ 3.61, 6.97, 8.16, 0.00, 0.00, 0.00, 0.30 ], [ 4.48, 7.47, 9.05, 0.22, 0.01, 0.06, 0.35 ], [ 5.54, 7.52, 10.09, 0.10, 0.00, 0.03, 0.38 ], [ 5.93, 7.81, 10.54, 0.10, 0.00, 0.03, 0.43 ], [ 6.12, 8.03, 10.79, 0.02, 0.01, 0.01, 0.47 ], [ 6.11, 7.64, 10.46, 0.03, 0.00, 0.01, 0.47 ], [ 8.17, 8.65, 12.93, 0.00, 0.01, 0.00, 0.53 ], [ 3.24, 9.45, 11.15, 0.00, 0.02, 0.00, 0.55 ], [ 1.44, 7.56, 8.45, 0.00, 0.01, 0.00, 0.45 ], [ 5.35, 9.41, 11.81, 0.00, 0.01, 0.00, 0.57 ], [ 3.27, 9.10, 10.87, 0.01, 0.00, 0.00, 0.52 ], [ 4.97, 8.53, 10.86, 0.02, 0.00, 0.00, 0.53 ], [ 2.95, 7.21, 8.05, 0.15, 0.00, 0.11, 0.37 ], [ 2.95, 7.21, 8.05, 0.15, 0.00, 0.11, 0.37 ], [ 1.27, 8.35, 8.66, 0.07, 0.00, 0.04, 0.45 ], [ 1.27, 8.35, 8.66, 0.07, 0.00, 0.04, 0.45 ], [ 4.43, 8.48, 10.64, 0.08, 0.00, 0.03, 0.52 ], [ 1.83, 8.07, 9.16, 0.00, 0.00, 0.00, 0.47 ], [ 2.02, 8.19, 9.37, 0.00, 0.00, 0.00, 0.50 ], [ 8.37, 12.51, 15.93, 0.12, 0.00, 0.02, 0.60 ], [ 7.29, 8.36, 12.16, 0.03, 0.00, 0.02, 0.47 ], [ 1.28, 5.89, 6.14, 0.00, 0.00, 0.00, 0.30 ], [ 0.57, 5.34, 5.40, 0.00, 0.00, 0.00, 0.23 ], [ 2.81, 7.23, 8.17, 0.00, 0.00, 0.00, 0.38 ], [ 6.36, 8.52, 11.39, 0.00, 0.00, 0.00, 0.52 ], [ 2.66, 8.55, 10.05, 0.13, 0.00, 0.02, 0.50 ], [ 3.67, 8.98, 10.92, 0.01, 0.00, 0.00, 0.50 ], [ 4.78, 9.18, 12.23, 0.01, 0.00, 0.00, 0.53 ], [ 4.56, 9.59, 12.49, 0.00, 0.00, 0.00, 0.53 ], [ 5.66, 9.83, 12.86, 0.00, 0.00, 0.00, 0.58 ], [ 0.97, 9.81, 10.04, 0.28, 0.00, 0.05, 0.53 ], [ 4.38, 9.30, 11.49, 0.16, 0.00, 0.03, 0.52 ], [ 6.10, 11.69, 14.29, 0.12, 0.00, 0.03, 0.58 ], [ 2.55, 8.49, 9.94, 0.02, 0.00, 0.00, 0.50 ], [ 6.56, 11.02, 14.39, 0.02, 0.00, 0.00, 0.50 ], [ 3.16, 7.44, 9.01, 0.08, 0.00, 0.04, 0.45 ], [ 8.24, 12.09, 15.39, 0.02, 0.00, 0.00, 0.60 ], [ 2.93, 6.48, 7.15, 0.21, 0.00, 0.05, 0.32 ], [ 2.93, 6.48, 7.15, 0.21, 0.00, 0.05, 0.32 ], [ 6.04, 9.67, 12.01, 2.02, 0.01, 0.66, 0.52 ], [ 4.58, 8.93, 10.23, 0.43, 0.01, 0.17, 0.53 ], [ 3.87, 8.08, 10.05, 0.03, 0.00, 0.02, 0.47 ], [ 6.99, 8.96, 12.05, 0.20, 0.00, 0.05, 0.55 ], [ 5.82, 8.36, 10.86, 0.01, 0.01, 0.01, 0.48 ], [ 0.06, 6.45, 6.50, 0.00, 0.01, 0.00, 0.30 ], [ 0.06, 6.45, 6.50, 0.00, 0.01, 0.00, 0.30 ], [ 0.06, 6.45, 6.50, 0.00, 0.01, 0.00, 0.30 ], [ 3.08, 7.49, 8.66, 0.07, 0.00, 0.05, 0.42 ], [ 2.03, 7.29, 7.96, 0.01, 0.01, 0.00, 0.38 ], [ 0.47, 4.18, 4.22, 0.00, 0.00, 0.00, 0.23 ], [ 3.55, 7.79, 9.67, 0.29, 0.01, 0.11, 0.45 ], [ 4.60, 7.30, 9.19, 0.02, 0.00, 0.01, 0.37 ], [ 4.95, 8.14, 9.93, 0.04, 0.01, 0.04, 0.45 ], [ 0.88, 8.04, 8.51, 0.04, 0.01, 0.04, 0.48 ], [ 1.80, 7.19, 7.80, 0.00, 0.01, 0.00, 0.38 ], [ 0.74, 0.60, 1.13, 0.00, 0.01, 0.00, 0.28 ], [ 22.44, 11.27, 29.96, 2.38, 0.06, 1.16, 2.80 ], [ 1.47, 6.41, 7.47, 0.04, 0.00, 0.01, 0.32 ], [ 4.77, 9.41, 11.71, 0.00, 0.00, 0.00, 0.53 ], [ 3.58, 8.36, 10.31, 0.01, 0.01, 0.01, 0.47 ], [ 2.29, 9.25, 10.34, 0.00, 0.00, 0.00, 0.55 ],[ 2.42, 7.31, 8.41, 0.00, 0.01, 0.01, 0.38 ], [ 3.77, 5.87, 7.53, 0.07, 0.00, 0.03, 0.28 ], [ 11.11, 13.72, 19.79, 2.22, 0.03, 0.67, 1.78 ], [ 8.08, 9.78, 13.84, 0.43, 0.00, 0.15, 0.52 ], [ 0.95, 6.14, 6.31, 0.00, 0.00, 0.00, 0.28 ], [ 5.77, 9.75, 12.30, 0.00, 0.00, 0.00, 0.52 ], [ 1.27, 7.35, 8.11, 0.11, 0.00, 0.02, 0.43 ], [ 1.51, 7.40, 8.72, 0.15, 0.01, 0.03, 0.43 ], [ 5.88, 10.93, 13.96, 0.15, 0.01, 0.03, 0.57 ], [ 7.13, 9.18, 12.31, 0.11, 0.00, 0.02, 0.57 ], [ 4.11, 8.04, 10.12, 0.02, 0.00, 0.01, 0.47 ], [ 6.47, 7.62, 10.93, 0.01, 0.00, 0.00, 0.43 ], [ 6.49, 8.14, 11.15, 0.02, 0.00, 0.01, 0.47 ], [ 7.21, 8.36, 12.19, 0.02, 0.00, 0.00, 0.47 ], [ 2.41, 6.37, 7.56, 0.02, 0.00, 0.02, 0.28 ], [ 0.21, 7.31, 7.39, 0.01, 0.00, 0.00, 0.38 ], [ 5.85, 9.93, 12.50, 0.02, 0.00, 0.00, 0.52 ], [ 3.14, 7.32, 8.58, 0.04, 0.00, 0.02, 0.37 ], [ 8.59, 9.26, 13.83, 0.04, 0.00, 0.02, 0.53 ], [ 8.52, 9.33, 13.71, 0.25, 0.00, 0.05, 0.53 ], [ 8.35, 8.90, 13.40, 0.08, 0.00, 0.01, 0.52 ], [ 10.00, 11.60, 16.66, 0.03, 0.00, 0.00, 0.63 ], [ 0.00, 3.72, 3.72, 0.00, 0.00, 0.00, 0.23 ], [ 5.97, 8.84, 11.31, 0.05, 0.00, 0.02, 0.53 ], [ 4.82, 8.47, 10.74, 0.17, 0.00, 0.03, 0.48 ], [ 3.87, 7.96, 9.93, 0.02, 0.00, 0.00, 0.43 ], [ 5.74, 11.04, 13.56, 0.01, 0.00, 0.00, 0.60 ], [ 6.04, 8.32, 11.07, 0.00, 0.00, 0.00, 0.47 ], [ 5.89, 13.13, 15.64, 0.00, 0.00, 0.00, 0.67 ], [ 7.60, 8.60, 12.42, 0.00, 0.00, 0.00, 0.52 ], [ 1.19, 7.73, 8.49, 0.00, 0.00, 0.00, 0.45 ], [ 3.56, 8.29, 10.17, 0.00, 0.00, 0.00, 0.52 ], [ 7.66, 10.96, 14.54, 0.00, 0.00, 0.00, 0.58 ], [ 5.63, 11.13, 13.64, 0.00, 0.00, 0.00, 0.58 ], [ 4.24, 8.19, 10.27, 0.00, 0.00, 0.00, 0.47 ], [ 4.98, 9.35, 11.71, 0.07, 0.00, 0.01, 0.53 ], [ 2.99, 7.61, 9.15, 0.01, 0.00, 0.00, 0.45 ], [ 3.83, 8.83, 10.85, 0.10, 0.00, 0.05, 0.53 ], [ 1.76, 6.78, 7.22, 0.00, 0.00, 0.00, 0.28 ], [ 3.03, 7.49, 8.56, 0.00, 0.00, 0.00, 0.38 ], [ 3.19, 7.51, 8.63, 0.00, 0.00, 0.00, 0.37 ], [ 5.04, 8.58, 10.91, 0.00, 0.00, 0.00, 0.52 ], [ 3.19, 9.64, 10.26, 0.00, 0.00, 0.00, 0.55 ], [ 5.11, 8.54, 10.68, 0.00, 0.00, 0.00, 0.52 ], [ 7.23, 9.52, 12.97, 0.00, 0.00, 0.00, 0.50 ], [ 7.42, 10.08, 13.43, 0.00, 0.00, 0.00, 0.58 ], [ 7.34, 8.82, 12.35, 0.00, 0.00, 0.00, 0.52 ], [ 7.80, 10.52, 14.09, 0.00, 0.00, 0.00, 0.53 ], [ 7.34, 8.67, 12.37, 1.13, 0.00, 0.27, 0.53 ], [ 2.00, 1.68, 3.08, 0.02, 0.00, 0.00, 0.15 ], [ 0.71, 6.28, 6.39, 0.00, 0.00, 0.00, 0.32 ], [ 6.05, 10.48, 13.10, 0.01, 0.00, 0.01, 0.60 ], [ 2.63, 7.33, 8.61, 0.01, 0.00, 0.01, 0.37 ],[ 3.52, 5.41, 7.18, 0.06, 0.00, 0.03, 0.22 ], [ 2.85, 8.62, 10.23, 0.03, 0.00, 0.02, 0.53 ], [ 5.77, 7.53, 10.46, 0.38, 0.00, 0.16, 0.38 ], [ 7.29, 7.80, 11.88, 0.21, 0.00, 0.10, 0.47 ], [ 4.28, 6.41, 8.24, 0.18, 0.00, 0.12, 0.30 ], [ 2.76, 6.78, 8.17, 0.00, 0.01, 0.00, 0.32 ], [ 9.54, 10.42, 15.45, 0.14, 0.01, 0.05, 0.60 ], [ 7.68, 9.07, 12.98, 0.09, 0.01, 0.02, 0.52 ], [ 6.98, 10.23, 13.72, 0.10, 0.00, 0.02, 0.53 ], [ 6.71, 9.51, 12.98, 0.15, 0.00, 0.02, 0.50 ], [ 7.73, 8.65, 12.79, 0.06, 0.00, 0.01, 0.52 ], [ 6.43, 9.94, 13.34, 0.16, 0.00, 0.03, 0.53 ], [ 8.01, 9.29, 13.50, 0.17, 0.00, 0.03, 0.53 ], [ 6.36, 10.46, 13.75, 0.03, 0.00, 0.00, 0.53 ], [ 8.20, 10.19, 14.59, 0.14, 0.00, 0.02, 0.58 ], [ 8.35, 9.77, 13.97, 0.24, 0.00, 0.05, 0.53 ], [ 8.27, 9.60, 14.06, 0.15, 0.00, 0.03, 0.57 ], [ 7.34, 10.29, 14.10, 0.10, 0.00, 0.01, 0.53 ], [ 7.53, 9.19, 13.19, 0.13, 0.00, 0.02, 0.53 ], [ 8.08, 10.06, 14.45, 0.15, 0.00, 0.02, 0.58 ], [ 6.73, 9.27, 12.68, 0.17, 0.00, 0.03, 0.53 ], [ 6.80, 10.65, 14.25, 0.14, 0.00, 0.02, 0.60 ], [ 8.51, 8.87, 13.46, 0.02, 0.00, 0.01, 0.53 ], [ 6.74, 8.96, 11.76, 0.06, 0.00, 0.01, 0.53 ], [ 8.93, 9.89, 14.35, 0.22, 0.00, 0.04, 0.55 ], [ 8.57, 9.81, 14.13, 0.20, 0.00, 0.03, 0.55 ], [ 7.53, 9.40, 13.26, 0.18, 0.00, 0.03, 0.53 ], [ 7.81, 8.92, 13.20, 0.19, 0.00, 0.03, 0.55 ], [ 8.19, 8.98, 13.38, 0.20, 0.00, 0.03, 0.53 ], [ 6.74, 8.74, 12.32, 0.17, 0.00, 0.03, 0.50 ], [ 7.68, 9.38, 13.32, 0.13, 0.00, 0.05, 0.50 ], [ 0.22, 5.73, 5.75, 0.02, 0.00, 0.02, 0.32 ], [ 7.20, 7.70, 11.76, 0.00, 0.01, 0.01, 0.47 ], [ 5.14, 7.05, 9.36, 0.04, 0.01, 0.02, 0.40 ], [ 5.33, 7.73, 10.06, 0.02, 0.00, 0.01, 0.47 ], [ 2.04, 7.52, 8.40, 0.36, 0.00, 0.12, 0.37 ], [ 3.06, 8.55, 10.26, 0.00, 0.00, 0.00, 0.47 ], [ 3.60, 8.94, 10.86, 0.00, 0.00, 0.00, 0.48 ], [ 3.90, 7.32, 8.65, 0.61, 0.00, 0.21, 0.32 ], [ 4.13, 7.90, 9.53, 1.23, 0.00, 0.43, 0.38 ], [ 0.00, 6.31, 6.31, 1.07, 0.00, 0.37, 0.32 ], [ 4.23, 8.07, 10.15, 1.07, 0.00, 0.37, 0.45 ], [ 4.26, 7.89, 9.90, 0.04, 0.01, 0.03, 0.45 ], [ 2.03, 7.82, 9.09, 0.03, 0.00, 0.01, 0.47 ], [ 2.00, 7.66, 8.86, 0.12, 0.00, 0.03, 0.40 ], [ 7.84, 8.68, 12.78, 0.01, 0.00, 0.00, 0.53 ], [ 6.02, 7.61, 10.73, 0.00, 0.00, 0.00, 0.40 ], [ 4.17, 7.46, 8.82, 0.12, 0.00, 0.03, 0.35 ], [ 0.50, 6.90, 7.00, 0.02, 0.00, 0.01, 0.30 ], [ 5.89, 11.07, 13.06, 0.02, 0.00, 0.01, 0.60 ], [ 2.03, 7.38, 8.47, 0.02, 0.00, 0.01, 0.37 ], [ 3.40, 7.83, 9.64, 0.01, 0.00, 0.01, 0.45 ], [ 2.34, 7.45, 8.30, 0.03, 0.00, 0.02, 0.37 ], [ 0.41, 7.54, 7.81, 0.01, 0.00, 0.00, 0.37 ], [ 3.41, 7.64, 9.22, 0.14, 0.00, 0.03, 0.45 ], [ 5.65, 8.09, 10.48, 0.07, 0.00, 0.02, 0.47 ], [ 3.42, 8.05, 9.91, 0.00, 0.00, 0.00, 0.47 ], [ 5.15, 7.13, 9.47, 0.00, 0.00, 0.01, 0.38 ], [ 3.90, 7.68, 9.47, 0.19, 0.00, 0.04, 0.45 ], [ 4.99, 10.45, 12.78, 0.19, 0.00, 0.04, 0.45 ], [ 4.49, 8.93, 11.16, 0.00, 0.00, 0.00, 0.52 ], [ 3.89, 9.30, 11.32, 0.00, 0.00, 0.00, 0.53 ], [ 7.14, 8.65, 12.07, 0.21, 0.01, 0.04, 0.53 ], [ 6.28, 7.60, 10.74, 0.01, 0.00, 0.00, 0.43 ], [ 6.80, 7.85, 11.43, 0.06, 0.00, 0.01, 0.43 ], [ 6.99, 7.96, 11.57, 0.00, 0.00, 0.00, 0.45 ], [ 1.50, 7.53, 8.36, 0.00, 0.00, 0.00, 0.38 ], [ 5.62, 7.51, 10.16, 0.00, 0.00, 0.00, 0.38 ], [ 7.30, 9.27, 12.52, 0.01, 0.00, 0.00, 0.53 ], [ 9.41, 12.43, 16.88, 0.19, 0.00, 0.03, 0.60 ], [ 4.03, 7.86, 10.21, 0.02, 0.00, 0.00, 0.47 ], [ 2.55, 8.25, 9.78, 0.02, 0.00, 0.02, 0.47 ],[ 3.37, 7.55, 9.12, 0.00, 0.01, 0.01, 0.40 ], [ 126.04, 15.25, 136.93, 2.37, 0.09, 2.31, 18.58 ], [ 6.74, 8.28, 11.66, 0.02, 0.00, 0.01, 0.47 ], [ 3.82, 7.97, 9.91, 0.02, 0.00, 0.00, 0.47 ], [ 3.12, 7.97, 9.71, 0.05, 0.01, 0.05, 0.47 ], [ 1.36, 8.06, 8.93, 0.01, 0.00, 0.00, 0.43 ], [ 0.84, 7.77, 8.50, 0.01, 0.00, 0.00, 0.47 ], [ 0.97, 7.88, 8.58, 0.01, 0.00, 0.00, 0.45 ], [ 1.62, 8.40, 9.55, 0.01, 0.00, 0.00, 0.52 ], [ 1.39, 7.75, 8.94, 0.00, 0.00, 0.00, 0.47 ], [ 2.58, 7.50, 8.78, 0.01, 0.00, 0.01, 0.37 ], [ 3.52, 7.40, 9.47, 0.01, 0.00, 0.00, 0.38 ], [ 8.03, 8.93, 13.10, 0.01, 0.01, 0.01, 0.55 ], [ 0.14, 7.51, 7.56, 0.01, 0.00, 0.00, 0.40 ], [ 2.87, 5.81, 7.38, 0.01, 0.00, 0.00, 0.30 ], [ 5.90, 7.76, 10.52, 0.01, 0.00, 0.00, 0.45 ], [ 7.01, 9.80, 12.80, 0.00, 0.01, 0.00, 0.52 ], [ 1.20, 7.47, 8.36, 0.03, 0.01, 0.01, 0.45 ], [ 2.64, 7.68, 9.18, 0.02, 0.00, 0.01, 0.43 ], [ 2.83, 8.02, 9.66, 0.00, 0.00, 0.00, 0.45 ], [ 1.26, 7.39, 7.82, 0.05, 0.00, 0.04, 0.38 ], [ 2.34, 0.94, 2.66, 0.00, 0.00, 0.00, 0.15 ], [ 1.49, 7.64, 8.61, 0.00, 0.00, 0.00, 0.42 ], [ 2.22, 7.36, 8.59, 0.01, 0.00, 0.05, 0.38 ], [ 4.38, 8.02, 10.68, 0.01, 0.00, 0.05, 0.47 ], [ 1.45, 7.12, 7.77, 0.03, 0.00, 0.03, 0.38 ], [ 0.11, 7.52, 7.55, 0.01, 0.00, 0.00, 0.37 ], [ 0.46, 7.30, 7.63, 0.00, 0.00, 0.00, 0.38 ], [ 0.69, 7.53, 7.93, 0.01, 0.00, 0.00, 0.37 ], [ 2.24, 7.50, 8.77, 0.01, 0.00, 0.00, 0.45 ], [ 1.23, 7.71, 8.42, 0.00, 0.00, 0.00, 0.43 ], [ 0.89, 7.44, 7.91, 0.01, 0.01, 0.01, 0.35 ], [ 0.72, 7.57, 8.04, 0.01, 0.00, 0.01, 0.40 ], [ 8.36, 8.54, 13.09, 0.87, 0.00, 0.26, 0.53 ], [ 2.57, 7.53, 8.69, 0.08, 0.00, 0.13, 0.38 ]]
timeLimit = 1.5 # seconds

# %%
# fill purist array

PuristTime = np.empty(len(PuristString))
PuristXZDistance = np.empty(len(PuristString))
PuristYDistance = np.empty(len(PuristString))
PuristTotalDistance = np.empty(len(PuristString))
PuristYawAngle = np.empty(len(PuristString))
PuristPitchAngle = np.empty(len(PuristString))
PuristTotalAngle = np.empty(len(PuristString))
PuristJumpNum = np.empty(len(PuristString))
PuristIterator = 0

for n in range(0, len(PuristString)):
    if(PuristString[n][6] < timeLimit):
        PuristTime[PuristIterator] = np.array(PuristString[n][6])
        PuristXZDistance[PuristIterator] = np.array(PuristString[n][0])
        PuristYDistance[PuristIterator] = np.array(PuristString[n][1])
        PuristTotalDistance[PuristIterator] = np.array(PuristString[n][2])
        PuristYawAngle[PuristIterator] = np.array(PuristString[n][3])
        PuristPitchAngle[PuristIterator] = np.array(PuristString[n][4])
        PuristTotalAngle[PuristIterator] = np.array(PuristString[n][5])
        PuristJumpNum[PuristIterator] = PuristIterator
        PuristIterator += 1
    else:
        print("Cut data at jump number " + str(n))

print(PuristIterator)

# time removal correction
PuristTime = PuristTime[:PuristIterator]
PuristXZDistance = PuristXZDistance[:PuristIterator]
PuristYDistance = PuristYDistance[:PuristIterator]
PuristTotalDistance = PuristTotalDistance[:PuristIterator]
PuristYawAngle = PuristYawAngle[:PuristIterator]
PuristPitchAngle = PuristPitchAngle[:PuristIterator]
PuristTotalAngle = PuristTotalAngle[:PuristIterator]
PuristJumpNum = PuristJumpNum[:PuristIterator]
# Out:
# Cut data at jump number 32
# Cut data at jump number 33
# Cut data at jump number 110
# Cut data at jump number 117
# Cut data at jump number 241
# 270

# %%
# fill CCO jump array

CCOTime = np.empty(len(CCOString))
CCOXZDistance = np.empty(len(CCOString))
CCOYDistance = np.empty(len(CCOString))
CCOTotalDistance = np.empty(len(CCOString))
CCOYawAngle = np.empty(len(CCOString))
CCOPitchAngle = np.empty(len(CCOString))
CCOTotalAngle = np.empty(len(CCOString))
CCOJumpNum = np.empty(len(CCOString))
CCOIterator = 0

for n in range(0, len(CCOString)):
    if(CCOString[n][6] < timeLimit):
        # if it's above timeLimit, its definitely a mistake, don't count it
        CCOTime[CCOIterator] = np.array(CCOString[n][6])   
        CCOXZDistance[CCOIterator] = np.array(CCOString[n][0])
        CCOYDistance[CCOIterator] = np.array(CCOString[n][1])
        CCOTotalDistance[CCOIterator] = np.array(CCOString[n][2])
        CCOYawAngle[CCOIterator] = np.array(CCOString[n][3])
        CCOPitchAngle[CCOIterator] = np.array(CCOString[n][4])
        CCOTotalAngle[CCOIterator] = np.array(CCOString[n][5])
        CCOJumpNum[CCOIterator] = CCOIterator
        CCOIterator += 1
    else:
        print("Cut data at jump number " + str(n))

print(CCOIterator)

# time removal correction
CCOTime = CCOTime[:CCOIterator]
CCOXZDistance = CCOXZDistance[:CCOIterator]
CCOYDistance = CCOYDistance[:CCOIterator]
CCOTotalDistance = CCOTotalDistance[:CCOIterator]
CCOYawAngle = CCOYawAngle[:CCOIterator]
CCOPitchAngle = CCOPitchAngle[:CCOIterator]
CCOTotalAngle = CCOTotalAngle[:CCOIterator]
CCOJumpNum = CCOJumpNum[:CCOIterator]
# Out:
# 32

# %%
# printing out averages and standard deviation

print("Stat Results: \n")
print("Average XZ Distance per Jump\nPurist: " + str(PuristXZDistance.mean()) + "\nCCO: " + str(CCOXZDistance.mean()))
print("\n")
print("Average Y Distance per Jump\nPurist: " + str(PuristYDistance.mean()) + "\nCCO: " + str(CCOYDistance.mean()))
print("\n")
print("Average Total Distance per Jump\nPurist: " + str(PuristTotalDistance.mean()) + "\nCCO: " + str(CCOTotalDistance.mean()))
print("\n")
print("Average Yaw Angle per Jump\nPurist: " + str(PuristYawAngle.mean()) + "\nCCO: " + str(CCOYawAngle.mean()))
print("\n")
print("Average Pitch Angle per Jump\nPurist: " + str(PuristPitchAngle.mean()) + "\nCCO: " + str(CCOPitchAngle.mean()))
print("\n")
print("Average Total Angle per Jump\nPurist: " + str(PuristTotalAngle.mean()) + "\nCCO: " + str(CCOTotalAngle.mean()))
print("\n")
print("Average Time per Jump\nPurist: " + str(PuristTime.mean()) + "\nCCO: " + str(CCOTime.mean()))

print("\n")

print("St. Dev. XZ Distance per Jump \nPurist: " + str(PuristXZDistance.std()) + "\nCCO: " + str(CCOXZDistance.std()))
print("\n")
print("St. Dev. Y Distance per Jump \nPurist: " + str(PuristYDistance.std()) + "\nCCO: " + str(CCOYDistance.std()))
print("\n")
print("St. Dev. Total Distance per Jump \nPurist: " + str(PuristTotalDistance.std()) + "\nCCO: " + str(CCOTotalDistance.std()))
print("\n")
print("St. Dev. Yaw Angle per Jump \nPurist: " + str(PuristYawAngle.std()) + "\nCCO: " + str(CCOYawAngle.std()))
print("\n")
print("St. Dev. Pitch Angle per Jump \nPurist: " + str(PuristPitchAngle.std()) + "\nCCO: " + str(CCOPitchAngle.std()))
print("\n")
print("St. Dev. Total Angle per Jump \nPurist: " + str(PuristTotalAngle.std()) + "\nCCO: " + str(CCOTotalAngle.std()))
print("\n")
print("St. Dev. Time per Jump \nPurist: " + str(PuristTime.std()) + "\nCCO: " + str(CCOTime.std()))
print("\n")
# Out:
# Stat Results:
#
# Average XZ Distance per Jump
# Purist: 4.286407407407407
# CCO: 6.0153125
#
#
# Average Y Distance per Jump
# Purist: 8.287555555555556
# CCO: 8.3040625
#
#
# Average Total Distance per Jump
# Purist: 10.37648148148148
# CCO: 11.365625
#
#
# Average Yaw Angle per Jump
# Purist: 0.08866666666666666
# CCO: 0.0871875
#
#
# Average Pitch Angle per Jump
# Purist: 0.0016296296296296297
# CCO: 0.003125
#
#
# Average Total Angle per Jump
# Purist: 0.03014814814814815
# CCO: 0.0425
#
#
# Average Time per Jump
# Purist: 0.4615185185185185
# CCO: 0.4659375
#
#
# St. Dev. XZ Distance per Jump
# Purist: 2.4449927782860743
# CCO: 2.511744891971267
#
#
# St. Dev. Y Distance per Jump
# Purist: 1.6057014005269847
# CCO: 1.3248510750623068
#
#
# St. Dev. Total Distance per Jump
# Purist: 2.5198083094401706
# CCO: 2.7191231784115626
#
#
# St. Dev. Yaw Angle per Jump
# Purist: 0.21131966306995664
# CCO: 0.10730314461258814
#
#
# St. Dev. Pitch Angle per Jump
# ...

# %%
# Plots (for visualization and the paper)

plt.plot(PuristJumpNum, PuristTime)
plt.title("ToCH Purist Airtime")
plt.xlabel("Jump Number")
plt.ylabel("Airtime (s)")
plt.show()

plt.plot(PuristJumpNum, PuristXZDistance)
plt.plot(PuristJumpNum, PuristYDistance)
plt.plot(PuristJumpNum, PuristTotalDistance)
plt.title("ToCH Purist Distance")
plt.xlabel("Jump Number")
plt.ylabel("XZ Distance (Studs)")
plt.legend(["XZ Distance","Y Distance","Total Distance"])
plt.show()

plt.plot(PuristJumpNum, PuristYawAngle)
plt.plot(PuristJumpNum, PuristPitchAngle)
plt.plot(PuristJumpNum, PuristTotalAngle)
plt.title("ToCH Purist Angle per Jump")
plt.xlabel("Jump Number")
plt.ylabel("Angle (rad)")
plt.legend(["Yaw Angle","Pitch Angle","Total Angle"])
plt.show()

plt.plot(CCOJumpNum, CCOTime)
plt.xlabel("Jump Number")
plt.ylabel("Airtime (s)")
plt.title("ToCH CCO Airtime")
plt.show()

plt.plot(CCOJumpNum, CCOXZDistance)
plt.plot(CCOJumpNum, CCOYDistance)
plt.plot(CCOJumpNum, CCOTotalDistance)
plt.title("ToCH CCO Distance")
plt.xlabel("Jump Number")
plt.ylabel("XZ Distance (Studs)")
plt.legend(["XZ Distance","Y Distance","Total Distance"])
plt.show()

plt.plot(CCOJumpNum, CCOYawAngle)
plt.plot(CCOJumpNum, CCOPitchAngle)
plt.plot(CCOJumpNum, CCOTotalAngle)
plt.title("ToCH Purist Angle per Jump")
plt.xlabel("Jump Number")
plt.ylabel("Angle (rad)")
plt.legend(["Yaw Angle","Pitch Angle","Total Angle"])
plt.show()
