# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# input data from Roblox console

PuristString = [[ 0.44, 6.69, 6.77, 0.00, 0.00, 0.00, 0.32 ], [ 7.43, 8.33, 12.33, 0.45, 0.00, 0.08, 0.47 ], [ 5.34, 7.37, 9.86, 0.47, 0.00, 0.19, 0.35 ], [ 2.69, 6.41, 7.26, 0.03, 0.01, 0.01, 0.32 ], [ 6.39, 8.74, 11.22, 0.04, 0.00, 0.02, 0.53 ], [ 5.04, 7.27, 9.58, 0.04, 0.00, 0.02, 0.37 ], [ 0.33, 7.52, 7.65, 0.00, 0.00, 0.00, 0.38 ], [ 3.93, 7.63, 9.59, 0.06, 0.00, 0.01, 0.45 ], [ 4.79, 10.93, 12.29, 0.14, 0.01, 0.05, 0.58 ], [ 0.00, 6.97, 6.97, 0.42, 0.00, 0.16, 0.32 ], [ 0.26, 6.08, 6.10, 0.04, 0.00, 0.01, 0.25 ], [ 0.34, 1.77, 1.81, 0.00, 0.00, 0.02, 0.25 ], [ 7.09, 7.99, 11.62, 1.60, 0.01, 0.94, 0.48 ], [ 0.54, 7.40, 7.77, 0.07, 0.00, 0.03, 0.45 ], [ 6.11, 7.98, 10.60, 1.58, 0.00, 0.76, 0.52 ], [ 0.04, 5.76, 5.76, 0.00, 0.00, 0.00, 0.25 ], [ 6.28, 7.67, 10.59, 0.68, 0.00, 0.12, 0.47 ], [ 17.73, 58.57, 63.97, 0.06, 0.00, 0.01, 1.12 ], [ 8.67, 9.19, 13.84, 0.21, 0.00, 0.05, 0.53 ], [ 5.93, 7.52, 10.51, 0.93, 0.00, 0.20, 0.37 ], [ 2.44, 6.73, 7.93, 0.26, 0.00, 0.07, 0.30 ], [ 7.94, 9.75, 13.37, 0.16, 0.01, 0.03, 0.55 ], [ 7.45, 8.47, 12.20, 0.41, 0.00, 0.09, 0.52 ], [ 7.94, 10.73, 14.46, 1.17, 0.00, 0.30, 0.55 ], [ 4.83, 7.28, 9.46, 1.29, 0.00, 0.28, 0.37 ], [ 2.60, 6.77, 8.06, 0.01, 0.00, 0.00, 0.30 ], [ 7.99, 9.16, 13.14, 1.44, 0.00, 0.30, 0.55 ], [ 7.95, 9.68, 13.54, 1.94, 0.00, 0.67, 0.55 ], [ 2.21, 6.02, 7.01, 0.01, 0.01, 0.00, 0.30 ], [ 0.01, 6.61, 6.61, 0.03, 0.00, 0.06, 0.30 ], [ 7.54, 9.74, 13.24, 0.03, 0.00, 0.00, 0.52 ], [ 8.61, 10.91, 15.06, 0.90, 0.00, 0.16, 0.55 ], [ 8.58, 9.98, 14.37, 1.07, 0.00, 0.22, 0.53 ], [ 9.61, 10.51, 15.57, 1.07, 0.00, 0.22, 0.60 ], [ 8.78, 9.75, 14.34, 0.11, 0.00, 0.01, 0.55 ], [ 7.09, 9.26, 12.48, 0.46, 0.00, 0.08, 0.52 ], [ 9.07, 10.15, 14.82, 0.01, 0.00, 0.00, 0.60 ], [ 8.38, 10.03, 14.23, 0.01, 0.00, 0.00, 0.53 ], [ 8.73, 10.41, 14.78, 0.07, 0.00, 0.02, 0.55 ], [ 7.67, 9.16, 12.77, 0.67, 0.00, 0.14, 0.53 ], [ 8.26, 9.34, 13.60, 0.19, 0.00, 0.11, 0.52 ], [ 5.51, 7.61, 10.14, 0.78, 0.01, 0.35, 0.37 ], [ 4.62, 7.22, 9.24, 0.28, 0.00, 0.14, 0.32 ], [ 8.28, 9.06, 13.13, 0.28, 0.00, 0.14, 0.52 ], [ 7.84, 8.29, 12.63, 0.39, 0.01, 0.12, 0.52 ], [ 4.48, 8.52, 10.72, 0.10, 0.01, 0.06, 0.53 ], [ 6.18, 7.53, 10.59, 0.01, 0.01, 0.01, 0.45 ], [ 7.22, 8.12, 11.83, 0.00, 0.00, 0.00, 0.45 ], [ 6.32, 7.59, 10.80, 0.01, 0.01, 0.00, 0.40 ], [ 9.00, 10.96, 15.40, 0.01, 0.01, 0.00, 0.57 ], [ 7.62, 9.15, 12.77, 0.66, 0.00, 0.15, 0.55 ], [ 8.16, 9.32, 13.31, 0.00, 0.00, 0.00, 0.53 ], [ 4.80, 7.40, 9.20, 0.50, 0.00, 0.13, 0.40 ], [ 4.07, 7.26, 8.56, 0.00, 0.00, 0.00, 0.38 ], [ 3.99, 7.24, 8.48, 0.00, 0.00, 0.00, 0.37 ], [ 5.17, 8.26, 10.05, 0.49, 0.00, 0.14, 0.52 ], [ 2.47, 6.40, 7.17, 0.01, 0.00, 0.00, 0.30 ], [ 6.80, 8.51, 11.62, 0.02, 0.01, 0.01, 0.50 ], [ 2.81, 4.43, 5.79, 0.12, 0.00, 0.06, 0.22 ], [ 12.68, 23.78, 28.67, 0.18, 0.00, 0.03, 0.85 ], [ 4.31, 7.02, 8.81, 0.11, 0.00, 0.02, 0.30 ], [ 1.01, 7.64, 8.24, 0.13, 0.00, 0.04, 0.45 ], [ 4.90, 8.35, 10.66, 0.09, 0.01, 0.03, 0.48 ], [ 4.57, 8.99, 10.28, 0.07, 0.00, 0.02, 0.55 ], [ 4.33, 8.40, 9.90, 0.61, 0.01, 0.19, 0.52 ], [ 1.83, 5.16, 5.89, 0.00, 0.00, 0.00, 0.22 ], [ 1.02, 7.19, 7.56, 0.58, 0.00, 0.27, 0.36 ], [ 9.44, 8.39, 15.07, 1.11, 0.02, 0.89, 2.08 ], [ 1.23, 4.28, 5.26, 0.07, 0.00, 0.03, 0.23 ], [ 7.66, 10.86, 14.29, 0.00, 0.00, 0.00, 0.55 ], [ 7.32, 8.28, 12.07, 0.13, 0.00, 0.06, 0.52 ], [ 7.22, 8.61, 12.16, 2.95, 0.01, 1.19, 0.53 ], [ 8.95, 10.98, 15.21, 0.02, 0.00, 0.00, 0.62 ], [ 0.00, 4.91, 4.91, 0.01, 0.00, 0.00, 0.25 ], [ 3.46, 6.04, 8.23, 0.01, 0.00, 0.00, 0.30 ], [ 8.68, 11.09, 14.97, 0.09, 0.01, 0.03, 0.60 ], [ 3.65, 5.86, 7.41, 0.42, 0.00, 0.13, 0.28 ], [ 1.78, 1.20, 2.34, 0.01, 0.00, 0.01, 0.22 ], [ 26.98, 10.79, 32.70, 2.08, 0.03, 0.88, 3.02 ], [ 1.27, 7.40, 7.83, 0.01, 0.00, 0.00, 0.38 ], [ 0.01, 3.56, 3.56, 0.01, 0.00, 0.01, 0.23 ], [ 14.42, 68.63, 74.64, 3.61, 0.03, 2.15, 3.78 ], [ 7.76, 9.57, 13.18, 0.18, 0.00, 0.08, 0.57 ], [ 8.02, 9.93, 13.89, 0.52, 0.00, 0.09, 0.53 ], [ 7.43, 8.74, 12.51, 0.31, 0.00, 0.06, 0.47 ], [ 6.96, 8.76, 12.13, 0.10, 0.00, 0.02, 0.53 ], [ 8.42, 8.69, 13.16, 0.04, 0.00, 0.01, 0.53 ], [ 6.18, 13.69, 16.23, 0.03, 0.00, 0.01, 0.62 ], [ 6.99, 8.95, 12.21, 0.00, 0.00, 0.00, 0.52 ], [ 7.57, 8.99, 12.60, 0.46, 0.00, 0.08, 0.53 ], [ 7.61, 8.79, 12.59, 0.75, 0.00, 0.13, 0.53 ], [ 7.92, 8.87, 12.89, 0.50, 0.00, 0.12, 0.53 ], [ 7.75, 9.26, 12.93, 0.73, 0.00, 0.13, 0.55 ], [ 5.10, 6.44, 9.11, 0.27, 0.00, 0.05, 0.33 ], [ 2.68, 7.63, 9.05, 0.01, 0.01, 0.00, 0.40 ], [ 6.70, 8.68, 11.80, 0.02, 0.02, 0.00, 0.52 ], [ 4.33, 8.44, 10.61, 0.02, 0.01, 0.00, 0.50 ], [ 7.12, 9.44, 12.40, 0.02, 0.00, 0.00, 0.55 ], [ 6.79, 9.36, 12.35, 0.01, 0.00, 0.00, 0.53 ], [ 4.15, 9.84, 11.92, 0.01, 0.00, 0.00, 0.53 ], [ 7.31, 9.33, 12.88, 0.01, 0.00, 0.00, 0.52 ], [ 7.77, 9.38, 13.17, 0.01, 0.00, 0.00, 0.55 ], [ 8.37, 9.23, 13.47, 0.03, 0.00, 0.00, 0.53 ], [ 7.08, 8.34, 11.77, 0.10, 0.00, 0.01, 0.52 ], [ 7.28, 8.73, 12.42, 0.04, 0.00, 0.00, 0.45 ], [ 5.28, 10.05, 12.48, 0.03, 0.00, 0.00, 0.53 ], [ 8.30, 11.18, 14.69, 0.13, 0.00, 0.02, 0.62 ], [ 8.39, 10.42, 14.52, 0.07, 0.00, 0.01, 0.53 ], [ 4.41, 8.93, 11.11, 0.65, 0.00, 0.11, 0.52 ], [ 7.11, 7.61, 11.57, 0.64, 0.00, 0.12, 0.47 ], [ 9.44, 13.36, 17.27, 0.90, 0.00, 0.15, 0.67 ], [ 2.67, 9.14, 10.60, 0.90, 0.00, 0.15, 0.67 ], [ 4.92, 16.68, 19.38, 0.09, 0.00, 0.10, 1.30 ], [ 7.20, 8.09, 12.06, 0.03, 0.00, 0.02, 0.45 ], [ 1.46, 7.91, 8.80, 0.00, 0.00, 0.00, 0.47 ], [ 8.44, 9.43, 13.74, 0.22, 0.00, 0.05, 0.53 ], [ 6.74, 7.55, 11.19, 0.43, 0.00, 0.08, 0.45 ], [ 2.01, 6.09, 6.79, 0.08, 0.00, 0.02, 0.30 ], [ 1.72, 7.99, 9.06, 0.79, 0.01, 0.21, 0.45 ], [ 3.86, 6.53, 7.84, 1.05, 0.00, 0.19, 0.32 ], [ 7.04, 9.05, 12.17, 0.56, 0.00, 0.11, 0.55 ], [ 7.11, 10.13, 13.42, 0.88, 0.00, 0.15, 0.60 ], [ 7.11, 8.69, 11.94, 0.81, 0.00, 0.15, 0.52 ], [ 7.62, 9.54, 13.00, 0.81, 0.00, 0.14, 0.53 ], [ 4.18, 6.45, 8.39, 0.24, 0.00, 0.06, 0.32 ], [ 0.19, 7.50, 7.59, 0.05, 0.01, 0.01, 0.40 ], [ 8.06, 9.21, 13.15, 0.94, 0.01, 0.20, 0.55 ], [ 8.49, 8.92, 13.48, 1.01, 0.00, 0.19, 0.53 ], [ 4.80, 7.07, 9.33, 0.13, 0.01, 0.03, 0.32 ], [ 0.33, 7.52, 7.68, 0.00, 0.00, 0.00, 0.38 ], [ 5.65, 7.97, 10.32, 0.01, 0.00, 0.01, 0.48 ], [ 7.29, 8.58, 12.13, 0.01, 0.00, 0.01, 0.50 ], [ 7.21, 8.06, 11.91, 0.10, 0.01, 0.03, 0.45 ], [ 8.10, 9.01, 13.37, 2.37, 0.00, 0.43, 0.50 ], [ 8.39, 9.26, 13.38, 1.57, 0.00, 0.29, 0.53 ], [ 8.13, 8.13, 12.74, 1.70, 0.00, 0.33, 0.52 ], [ 8.61, 9.81, 14.22, 1.17, 0.00, 0.20, 0.55 ], [ 8.40, 8.66, 13.33, 0.13, 0.01, 0.04, 0.53 ], [ 7.41, 9.85, 13.56, 0.64, 0.00, 0.11, 0.52 ], [ 0.02, 5.69, 5.69, 0.03, 0.00, 0.01, 0.28 ], [ 0.80, 7.91, 8.38, 0.19, 0.00, 0.03, 0.48 ], [ 7.96, 10.52, 14.36, 1.44, 0.00, 0.25, 0.60 ], [ 8.48, 9.66, 13.93, 1.81, 0.00, 0.32, 0.53 ], [ 5.71, 7.52, 10.30, 0.20, 0.00, 0.03, 0.38 ], [ 6.93, 10.64, 13.77, 1.53, 0.01, 0.28, 0.53 ], [ 7.66, 9.29, 13.33, 1.24, 0.00, 0.34, 0.52 ], [ 2.66, 8.73, 9.46, 1.03, 0.00, 0.25, 0.40 ], [ 2.39, 8.05, 9.45, 1.67, 0.01, 0.34, 0.45 ], [ 8.68, 10.00, 14.43, 0.94, 0.00, 0.17, 0.53 ], [ 9.98, 12.87, 17.46, 1.59, 0.01, 0.29, 0.63 ], [ 2.10, 7.53, 8.44, 0.10, 0.00, 0.04, 0.37 ], [ 6.49, 8.43, 11.45, 0.02, 0.00, 0.02, 0.47 ], [ 7.71, 8.78, 12.62, 0.01, 0.00, 0.01, 0.53 ], [ 4.70, 7.43, 9.11, 0.00, 0.00, 0.00, 0.38 ], [ 6.80, 7.78, 11.39, 0.02, 0.00, 0.01, 0.45 ], [ 7.71, 9.11, 12.97, 0.01, 0.01, 0.02, 0.48 ], [ 8.01, 10.42, 14.30, 1.63, 0.00, 0.35, 0.53 ], [ 5.94, 9.52, 11.99, 0.02, 0.00, 0.00, 0.58 ], [ 2.52, 5.84, 7.23, 0.02, 0.01, 0.01, 0.23 ], [ 8.40, 9.28, 13.82, 0.66, 0.00, 0.11, 0.52 ], [ 8.82, 10.28, 14.67, 0.12, 0.01, 0.02, 0.60 ], [ 8.22, 9.36, 13.46, 0.02, 0.02, 0.00, 0.55 ], [ 4.81, 7.51, 9.39, 0.54, 0.00, 0.11, 0.38 ], [ 7.09, 7.87, 11.61, 0.51, 0.00, 0.09, 0.45 ], [ 5.93, 7.32, 10.24, 1.81, 0.00, 0.40, 0.42 ], [ 0.02, 7.51, 7.51, 0.08, 0.01, 0.02, 0.37 ], [ 6.23, 7.63, 10.72, 0.05, 0.00, 0.03, 0.45 ], [ 6.01, 7.43, 10.39, 0.03, 0.00, 0.01, 0.38 ], [ 7.10, 9.31, 12.39, 0.00, 0.00, 0.00, 0.55 ], [ 7.20, 7.79, 11.95, 0.10, 0.00, 0.01, 0.43 ], [ 8.49, 8.58, 13.37, 0.17, 0.00, 0.03, 0.53 ], [ 7.98, 8.91, 12.99, 0.05, 0.00, 0.02, 0.50 ], [ 7.22, 8.23, 11.86, 0.02, 0.00, 0.00, 0.45 ], [ 5.63, 7.29, 10.17, 0.04, 0.00, 0.01, 0.35 ], [ 5.47, 7.47, 10.03, 0.04, 0.00, 0.02, 0.35 ], [ 6.84, 7.49, 11.23, 0.00, 0.00, 0.00, 0.43 ], [ 8.51, 8.64, 13.22, 0.04, 0.00, 0.01, 0.53 ], [ 8.65, 8.99, 13.70, 0.21, 0.00, 0.04, 0.55 ], [ 5.68, 7.45, 10.17, 0.04, 0.00, 0.01, 0.40 ], [ 8.28, 8.37, 12.89, 0.98, 0.01, 0.18, 0.52 ], [ 7.10, 8.25, 11.84, 0.15, 0.00, 0.02, 0.48 ], [ 8.03, 8.89, 13.09, 0.27, 0.00, 0.05, 0.50 ], [ 8.40, 10.24, 14.35, 0.02, 0.00, 0.00, 0.52 ], [ 7.76, 9.74, 13.58, 0.02, 0.00, 0.00, 0.52 ], [ 7.38, 8.02, 12.04, 0.03, 0.00, 0.00, 0.48 ], [ 8.99, 10.92, 15.26, 0.54, 0.00, 0.11, 0.62 ], [ 3.15, 7.00, 8.56, 0.03, 0.00, 0.02, 0.30 ], [ 3.95, 9.01, 10.99, 0.09, 0.00, 0.03, 0.53 ], [ 7.69, 9.09, 12.87, 0.03, 0.01, 0.03, 0.55 ], [ 4.50, 10.01, 12.21, 0.01, 0.00, 0.00, 0.52 ], [ 6.09, 7.67, 10.86, 0.41, 0.00, 0.08, 0.40 ], [ 6.06, 7.22, 10.32, 0.96, 0.00, 0.19, 0.38 ], [ 7.00, 9.00, 12.09, 0.07, 0.00, 0.01, 0.55 ], [ 7.84, 9.09, 13.01, 0.21, 0.00, 0.03, 0.52 ], [ 3.41, 7.53, 8.91, 0.18, 0.00, 0.03, 0.38 ], [ 7.18, 13.21, 16.04, 0.23, 0.00, 0.04, 0.67 ], [ 4.26, 9.55, 11.69, 0.02, 0.00, 0.01, 0.52 ], [ 4.64, 7.62, 9.28, 1.67, 0.00, 0.44, 0.45 ], [ 3.89, 7.51, 8.95, 1.26, 0.00, 0.34, 0.38 ], [ 0.55, 7.85, 8.20, 0.06, 0.01, 0.03, 0.47 ], [ 5.90, 8.88, 11.33, 0.08, 0.00, 0.02, 0.53 ], [ 6.98, 8.26, 11.80, 0.96, 0.00, 0.17, 0.47 ], [ 8.03, 9.75, 13.57, 1.61, 0.01, 0.34, 0.55 ], [ 8.72, 10.45, 14.64, 0.08, 0.00, 0.02, 0.60 ], [ 3.30, 7.38, 8.88, 0.00, 0.00, 0.00, 0.38 ], [ 8.43, 9.35, 13.66, 0.30, 0.00, 0.06, 0.53 ], [ 5.65, 8.09, 10.58, 0.05, 0.01, 0.03, 0.43 ], [ 6.82, 7.51, 11.19, 0.04, 0.00, 0.01, 0.45 ], [ 5.84, 7.52, 10.53, 0.02, 0.00, 0.00, 0.37 ], [ 6.22, 7.88, 11.10, 0.18, 0.00, 0.04, 0.40 ], [ 8.35, 8.76, 13.14, 0.14, 0.00, 0.05, 0.52 ], [ 8.72, 9.57, 14.02, 0.35, 0.00, 0.24, 0.55 ], [ 3.89, 6.11, 7.91, 0.36, 0.00, 0.19, 0.30 ], [ 6.22, 8.89, 11.50, 0.02, 0.00, 0.01, 0.53 ], [ 3.50, 5.48, 7.11, 0.04, 0.00, 0.02, 0.28 ], [ 2.48, 8.92, 10.98, 0.45, 0.01, 0.19, 0.80 ], [ 11.09, 18.66, 23.18, 0.13, 0.00, 0.05, 0.70 ], [ 6.13, 8.65, 11.22, 0.05, 0.01, 0.02, 0.53 ], [ 8.61, 10.99, 15.17, 0.23, 0.00, 0.06, 0.55 ], [ 1.05, 0.99, 1.53, 0.14, 0.00, 0.12, 0.23 ], [ 8.98, 8.53, 14.60, 1.58, 0.01, 0.85, 1.47 ], [ 8.26, 8.63, 13.04, 0.02, 0.00, 0.02, 0.52 ], [ 8.50, 9.94, 13.85, 0.02, 0.00, 0.02, 0.53 ], [ 7.36, 8.65, 12.25, 0.00, 0.00, 0.00, 0.54 ], [ 5.36, 7.18, 9.74, 1.86, 0.00, 0.47, 0.38 ], [ 8.79, 10.20, 14.36, 1.59, 0.00, 0.41, 0.57 ], [ 6.12, 7.66, 10.79, 0.17, 0.00, 0.03, 0.40 ], [ 1.49, 6.23, 6.53, 0.01, 0.00, 0.00, 0.30 ], [ 5.80, 7.83, 10.39, 0.03, 0.00, 0.01, 0.45 ], [ 6.04, 7.29, 10.28, 0.06, 0.00, 0.02, 0.42 ], [ 10.83, 17.92, 22.07, 0.02, 0.00, 0.00, 0.73 ], [ 6.80, 8.72, 11.74, 0.01, 0.00, 0.00, 0.53 ], [ 7.12, 8.81, 12.14, 0.02, 0.00, 0.01, 0.52 ], [ 8.21, 10.15, 14.14, 0.02, 0.00, 0.01, 0.53 ], [ 8.60, 10.55, 14.75, 0.00, 0.00, 0.00, 0.60 ], [ 7.63, 8.86, 12.70, 0.00, 0.00, 0.00, 0.50 ], [ 7.44, 8.69, 12.29, 0.01, 0.00, 0.01, 0.53 ], [ 5.33, 7.22, 9.54, 1.75, 0.00, 0.45, 0.38 ], [ 0.00, 7.66, 7.66, 0.18, 0.00, 0.08, 0.45 ], [ 2.96, 6.39, 7.94, 0.02, 0.00, 0.02, 0.28 ], [ 0.02, 7.11, 7.11, 0.02, 0.00, 0.02, 0.30 ], [ 8.12, 9.33, 13.53, 0.75, 0.00, 0.14, 0.52 ], [ 8.38, 9.66, 13.84, 0.72, 0.00, 0.13, 0.53 ], [ 6.08, 7.67, 10.44, 0.64, 0.00, 0.13, 0.47 ], [ 7.50, 8.75, 12.64, 0.31, 0.01, 0.06, 0.47 ], [ 6.79, 7.72, 11.31, 0.25, 0.00, 0.04, 0.45 ], [ 3.83, 6.67, 7.91, 0.58, 0.00, 0.15, 0.32 ], [ 1.50, 7.21, 7.73, 0.03, 0.00, 0.07, 0.38 ], [ 5.12, 7.51, 9.65, 0.00, 0.00, 0.01, 0.45 ], [ 5.89, 7.51, 10.30, 0.00, 0.00, 0.00, 0.43 ], [ 6.03, 7.39, 10.32, 0.02, 0.00, 0.02, 0.43 ], [ 4.52, 7.31, 9.14, 0.03, 0.00, 0.02, 0.37 ], [ 3.16, 7.26, 8.98, 0.00, 0.01, 0.00, 0.32 ], [ 3.57, 7.16, 8.94, 0.00, 0.01, 0.00, 0.37 ], [ 4.61, 6.75, 8.83, 0.03, 0.00, 0.00, 0.32 ], [ 8.55, 10.66, 14.75, 0.86, 0.00, 0.16, 0.53 ], [ 7.66, 7.93, 12.15, 2.68, 0.01, 0.47, 0.48 ], [ 2.98, 7.49, 8.71, 0.11, 0.00, 0.02, 0.47 ], [ 0.77, 7.30, 7.75, 0.23, 0.00, 0.05, 0.40 ], [ 8.39, 8.97, 13.29, 0.05, 0.00, 0.02, 0.53 ], [ 3.84, 6.27, 7.80, 1.20, 0.00, 0.22, 0.32 ], [ 0.16, 7.30, 7.35, 0.03, 0.00, 0.01, 0.38 ], [ 6.98, 7.82, 11.50, 1.70, 0.00, 0.37, 0.47 ], [ 0.03, 5.65, 5.65, 0.01, 0.00, 0.00, 0.23 ], [ 8.43, 9.26, 13.53, 0.01, 0.00, 0.00, 0.53 ], [ 8.04, 8.86, 13.04, 1.40, 0.00, 0.25, 0.52 ], [ 3.35, 6.46, 7.44, 0.03, 0.00, 0.01, 0.30 ], [ 6.07, 7.90, 10.61, 0.03, 0.00, 0.01, 0.47 ], [ 7.67, 10.48, 13.64, 0.03, 0.00, 0.01, 0.60 ], [ 8.06, 10.10, 14.01, 0.04, 0.01, 0.01, 0.52 ], [ 7.86, 9.43, 13.36, 2.03, 0.00, 0.40, 0.50 ], [ 0.40, 6.41, 6.47, 0.04, 0.00, 0.01, 0.32 ], [ 0.94, 7.63, 8.21, 0.78, 0.00, 0.18, 0.47 ], [ 4.15, 6.52, 8.27, 0.51, 0.00, 0.16, 0.30 ], [ 0.89, 0.00, 0.89, 0.13, 0.00, 0.02, 0.08 ], [ 2.95, 7.28, 8.34, 0.03, 0.01, 0.06, 0.35 ], [ 8.66, 9.05, 13.75, 1.10, 0.00, 0.20, 0.55 ], [ 8.56, 8.99, 13.52, 0.02, 0.00, 0.00, 0.53 ], [ 9.08, 10.64, 15.04, 0.83, 0.00, 0.17, 0.60 ], [ 4.05, 6.72, 8.26, 0.02, 0.00, 0.01, 0.30 ],[ 6.75, 7.77, 11.17, 0.00, 0.00, 0.00, 0.47 ], [ 3.83, 8.34, 10.38, 0.04, 0.00, 0.01, 0.48 ], [ 5.38, 7.44, 9.93, 0.01, 0.00, 0.00, 0.42 ], [ 6.15, 7.74, 10.56, 0.00, 0.00, 0.00, 0.48 ], [ 7.58, 9.28, 13.00, 0.27, 0.00, 0.06, 0.52 ], [ 4.43, 7.57, 9.62, 0.23, 0.00, 0.13, 0.43 ], [ 7.29, 8.89, 12.51, 0.91, 0.00, 0.47, 0.47 ], [ 5.24, 7.76, 10.16, 0.05, 0.00, 0.03, 0.45 ], [ 2.45, 5.80, 6.35, 0.03, 0.00, 0.01, 0.30 ], [ 5.88, 9.83, 12.39, 0.05, 0.00, 0.02, 0.55 ], [ 8.08, 10.02, 13.98, 1.56, 0.00, 0.97, 0.52 ], [ 6.05, 7.66, 10.80, 0.39, 0.00, 0.20, 0.38 ], [ 3.97, 7.79, 9.94, 0.07, 0.01, 0.06, 0.47 ], [ 4.29, 8.01, 10.32, 0.02, 0.00, 0.00, 0.45 ], [ 2.92, 7.69, 9.23, 0.05, 0.00, 0.04, 0.38 ]]
CCOString = [[ 6.99, 9.89, 12.88, 0.03, 0.01, 0.01, 0.53 ],[ 5.18, 7.57, 9.63, 0.01, 0.00, 0.00, 0.43 ],[ 4.94, 7.52, 9.48, 0.01, 0.00, 0.00, 0.37 ],[ 6.82, 8.31, 11.78, 0.01, 0.00, 0.00, 0.45 ],[ 8.32, 10.24, 14.18, 0.01, 0.00, 0.00, 0.57 ],[ 4.67, 9.00, 11.27, 0.29, 0.00, 0.05, 0.52 ],[ 8.06, 10.49, 14.10, 0.73, 0.00, 0.14, 0.58 ],[ 7.65, 8.93, 12.90, 0.05, 0.00, 0.01, 0.48 ],[ 1.50, 6.34, 7.38, 0.01, 0.00, 0.00, 0.30 ],[ 1.14, 5.95, 6.64, 0.01, 0.00, 0.00, 0.30 ],[ 3.04, 6.98, 8.65, 0.00, 0.00, 0.00, 0.30 ],[ 5.68, 7.58, 10.23, 0.01, 0.00, 0.00, 0.40 ],[ 5.97, 7.57, 10.67, 0.00, 0.00, 0.00, 0.38 ],[ 7.69, 9.51, 13.31, 0.36, 0.01, 0.09, 0.52 ],[ 0.74, 7.04, 7.21, 0.03, 0.01, 0.01, 0.35 ],[ 3.54, 8.56, 10.47, 0.19, 0.00, 0.03, 0.47 ],[ 5.36, 7.80, 10.03, 0.03, 0.00, 0.00, 0.47 ],[ 5.96, 7.84, 10.53, 0.02, 0.00, 0.00, 0.47 ],[ 3.59, 7.92, 9.81, 0.01, 0.00, 0.00, 0.45 ],[ 9.83, 13.80, 18.29, 0.49, 0.00, 0.08, 0.62 ],[ 5.00, 7.29, 9.27, 0.09, 0.00, 0.02, 0.40 ],[ 8.63, 10.32, 14.54, 1.13, 0.01, 0.22, 0.55 ],[ 3.61, 8.37, 10.34, 0.12, 0.00, 0.29, 0.48 ],[ 5.73, 7.52, 10.28, 0.00, 0.00, 0.00, 0.38 ],[ 5.72, 7.32, 10.13, 0.02, 0.00, 0.01, 0.37 ],[ 8.44, 9.52, 13.89, 0.55, 0.01, 0.19, 0.53 ],[ 0.95, 5.51, 6.17, 0.00, 0.00, 0.00, 0.28 ],[ 2.92, 7.17, 8.64, 0.00, 0.00, 0.00, 0.30 ],[ 6.97, 9.18, 12.06, 0.15, 0.01, 0.04, 0.53 ],[ 4.07, 6.90, 8.44, 0.02, 0.01, 0.00, 0.32 ],[ 8.72, 9.73, 14.14, 0.01, 0.00, 0.01, 0.55 ],[ 8.31, 8.95, 13.38, 0.14, 0.00, 0.04, 0.55 ],[ 6.74, 8.26, 11.52, 0.08, 0.01, 0.03, 0.47 ],[ 6.44, 7.84, 11.03, 0.02, 0.01, 0.00, 0.48 ],[ 7.28, 7.99, 11.82, 0.00, 0.01, 0.00, 0.47 ],[ 5.65, 7.18, 9.89, 0.00, 0.01, 0.00, 0.40 ],[ 6.14, 7.73, 10.71, 0.62, 0.01, 0.20, 0.45 ],[ 3.97, 7.23, 9.29, 0.02, 0.00, 0.01, 0.37 ],[ 7.59, 10.25, 13.53, 0.00, 0.00, 0.00, 0.55 ],[ 6.79, 9.59, 12.37, 0.36, 0.00, 0.09, 0.55 ],[ 2.84, 6.71, 8.18, 0.02, 0.00, 0.01, 0.28 ],[ 4.93, 9.72, 12.08, 0.10, 0.00, 0.02, 0.53 ],[ 5.55, 9.22, 11.70, 0.57, 0.00, 0.14, 0.55 ],[ 3.43, 7.72, 9.31, 0.56, 0.00, 0.13, 0.33 ],[ 5.38, 7.45, 9.95, 0.07, 0.00, 0.01, 0.40 ],[ 7.74, 8.91, 12.75, 2.19, 0.00, 0.39, 0.55 ],[ 0.15, 6.08, 6.10, 0.03, 0.00, 0.01, 0.30 ],[ 7.55, 8.91, 12.43, 0.02, 0.01, 0.07, 0.53 ],[ 7.68, 9.47, 13.23, 1.02, 0.00, 0.18, 0.52 ],[ 3.38, 8.47, 10.33, 0.01, 0.00, 0.00, 0.52 ],[ 5.09, 8.67, 11.03, 0.05, 0.00, 0.00, 0.55 ],[ 2.30, 7.30, 8.52, 0.14, 0.01, 0.03, 0.38 ],[ 4.52, 8.14, 10.33, 0.09, 0.00, 0.14, 0.45 ],[ 7.23, 8.35, 12.14, 0.32, 0.00, 0.05, 0.47 ],[ 5.03, 8.91, 11.22, 0.01, 0.00, 0.00, 0.53 ],[ 7.06, 9.29, 12.48, 0.00, 0.00, 0.00, 0.52 ],[ 7.32, 8.06, 11.92, 0.02, 0.00, 0.00, 0.48 ],[ 0.00, 5.19, 5.19, 0.70, 0.00, 0.12, 0.23 ],[ 4.11, 8.43, 10.53, 0.31, 0.00, 0.06, 0.53 ],[ 8.75, 10.21, 14.58, 1.11, 0.00, 0.22, 0.55 ],[ 6.93, 7.50, 11.16, 0.22, 0.00, 0.05, 0.43 ],[ 4.92, 7.39, 9.37, 0.02, 0.00, 0.01, 0.43 ],[ 3.03, 7.44, 9.03, 0.00, 0.00, 0.00, 0.42 ],[ 8.17, 10.19, 14.15, 0.79, 0.00, 0.15, 0.55 ],[ 1.30, 6.55, 6.86, 0.02, 0.00, 0.02, 0.30 ],[ 8.11, 9.75, 13.65, 0.12, 0.00, 0.03, 0.55 ],[ 5.18, 7.31, 9.60, 0.01, 0.00, 0.00, 0.38 ],[ 2.34, 7.20, 7.95, 0.05, 0.00, 0.01, 0.38 ],[ 7.89, 9.85, 13.65, 0.77, 0.00, 0.13, 0.52 ],[ 10.83, 16.88, 21.40, 0.04, 0.00, 0.00, 0.73 ],[ 2.92, 7.69, 9.23, 0.05, 0.00, 0.04, 0.38 ]]
timeLimit = 1.5 # seconds

# %%
# fill purist array

PuristTime = np.empty(len(PuristString))
PuristXZDistance = np.empty(len(PuristString))
PuristYDistance = np.empty(len(PuristString))
PuristTotalDistance = np.empty(len(PuristString))
PuristYawAngle = np.empty(len(PuristString))
PuristPitchAngle = np.empty(len(PuristString))
PuristTotalAngle = np.empty(len(PuristString))
PuristJumpNum = np.empty(len(PuristString))
PuristIterator = 0

for n in range(0, len(PuristString)):
    if(PuristString[n][6] < timeLimit):
        PuristTime[PuristIterator] = np.array(PuristString[n][6])
        PuristXZDistance[PuristIterator] = np.array(PuristString[n][0])
        PuristYDistance[PuristIterator] = np.array(PuristString[n][1])
        PuristTotalDistance[PuristIterator] = np.array(PuristString[n][2])
        PuristYawAngle[PuristIterator] = np.array(PuristString[n][3])
        PuristPitchAngle[PuristIterator] = np.array(PuristString[n][4])
        PuristTotalAngle[PuristIterator] = np.array(PuristString[n][5])
        PuristJumpNum[PuristIterator] = PuristIterator
        PuristIterator += 1
    else:
        print("Cut data at jump number " + str(n))

print(PuristIterator)

# time removal correction
PuristTime = PuristTime[:PuristIterator]
PuristXZDistance = PuristXZDistance[:PuristIterator]
PuristYDistance = PuristYDistance[:PuristIterator]
PuristTotalDistance = PuristTotalDistance[:PuristIterator]
PuristYawAngle = PuristYawAngle[:PuristIterator]
PuristPitchAngle = PuristPitchAngle[:PuristIterator]
PuristTotalAngle = PuristTotalAngle[:PuristIterator]
PuristJumpNum = PuristJumpNum[:PuristIterator]
# Out:
# Cut data at jump number 67
# Cut data at jump number 78
# Cut data at jump number 81
# 292

# %%
# fill CCO jump array

CCOTime = np.empty(len(CCOString))
CCOXZDistance = np.empty(len(CCOString))
CCOYDistance = np.empty(len(CCOString))
CCOTotalDistance = np.empty(len(CCOString))
CCOYawAngle = np.empty(len(CCOString))
CCOPitchAngle = np.empty(len(CCOString))
CCOTotalAngle = np.empty(len(CCOString))
CCOJumpNum = np.empty(len(CCOString))
CCOIterator = 0

for n in range(0, len(CCOString)):
    if(CCOString[n][6] < timeLimit):
        # if it's above timeLimit, its definitely a mistake, don't count it
        CCOTime[CCOIterator] = np.array(CCOString[n][6])   
        CCOXZDistance[CCOIterator] = np.array(CCOString[n][0])
        CCOYDistance[CCOIterator] = np.array(CCOString[n][1])
        CCOTotalDistance[CCOIterator] = np.array(CCOString[n][2])
        CCOYawAngle[CCOIterator] = np.array(CCOString[n][3])
        CCOPitchAngle[CCOIterator] = np.array(CCOString[n][4])
        CCOTotalAngle[CCOIterator] = np.array(CCOString[n][5])
        CCOJumpNum[CCOIterator] = CCOIterator
        CCOIterator += 1
    else:
        print("Cut data at jump number " + str(n))

print(CCOIterator)

# time removal correction
CCOTime = CCOTime[:CCOIterator]
CCOXZDistance = CCOXZDistance[:CCOIterator]
CCOYDistance = CCOYDistance[:CCOIterator]
CCOTotalDistance = CCOTotalDistance[:CCOIterator]
CCOYawAngle = CCOYawAngle[:CCOIterator]
CCOPitchAngle = CCOPitchAngle[:CCOIterator]
CCOTotalAngle = CCOTotalAngle[:CCOIterator]
CCOJumpNum = CCOJumpNum[:CCOIterator]
# Out:
# 71

# %%
# printing out averages and standard deviation

print("Stat Results: \n")
print("Average XZ Distance per Jump\nPurist: " + str(PuristXZDistance.mean()) + "\nCCO: " + str(CCOXZDistance.mean()))
print("\n")
print("Average Y Distance per Jump\nPurist: " + str(PuristYDistance.mean()) + "\nCCO: " + str(CCOYDistance.mean()))
print("\n")
print("Average Total Distance per Jump\nPurist: " + str(PuristTotalDistance.mean()) + "\nCCO: " + str(CCOTotalDistance.mean()))
print("\n")
print("Average Yaw Angle per Jump\nPurist: " + str(PuristYawAngle.mean()) + "\nCCO: " + str(CCOYawAngle.mean()))
print("\n")
print("Average Pitch Angle per Jump\nPurist: " + str(PuristPitchAngle.mean()) + "\nCCO: " + str(CCOPitchAngle.mean()))
print("\n")
print("Average Total Angle per Jump\nPurist: " + str(PuristTotalAngle.mean()) + "\nCCO: " + str(CCOTotalAngle.mean()))
print("\n")
print("Average Time per Jump\nPurist: " + str(PuristTime.mean()) + "\nCCO: " + str(CCOTime.mean()))

print("\n")

print("St. Dev. XZ Distance per Jump \nPurist: " + str(PuristXZDistance.std()) + "\nCCO: " + str(CCOXZDistance.std()))
print("\n")
print("St. Dev. Y Distance per Jump \nPurist: " + str(PuristYDistance.std()) + "\nCCO: " + str(CCOYDistance.std()))
print("\n")
print("St. Dev. Total Distance per Jump \nPurist: " + str(PuristTotalDistance.std()) + "\nCCO: " + str(CCOTotalDistance.std()))
print("\n")
print("St. Dev. Yaw Angle per Jump \nPurist: " + str(PuristYawAngle.std()) + "\nCCO: " + str(CCOYawAngle.std()))
print("\n")
print("St. Dev. Pitch Angle per Jump \nPurist: " + str(PuristPitchAngle.std()) + "\nCCO: " + str(CCOPitchAngle.std()))
print("\n")
print("St. Dev. Total Angle per Jump \nPurist: " + str(PuristTotalAngle.std()) + "\nCCO: " + str(CCOTotalAngle.std()))
print("\n")
print("St. Dev. Time per Jump \nPurist: " + str(PuristTime.std()) + "\nCCO: " + str(CCOTime.std()))
print("\n")
# Out:
# Stat Results:
#
# Average XZ Distance per Jump
# Purist: 5.831541095890411
# CCO: 5.464788732394366
#
#
# Average Y Distance per Jump
# Purist: 8.599041095890412
# CCO: 8.38943661971831
#
#
# Average Total Distance per Jump
# Purist: 11.405650684931507
# CCO: 10.999014084507042
#
#
# Average Yaw Angle per Jump
# Purist: 0.37476027397260275
# CCO: 0.21211267605633802
#
#
# Average Pitch Angle per Jump
# Purist: 0.0017123287671232876
# CCO: 0.0019718309859154933
#
#
# Average Total Angle per Jump
# Purist: 0.09702054794520547
# CCO: 0.050563380281690135
#
#
# Average Time per Jump
# Purist: 0.4711986301369863
# CCO: 0.45366197183098594
#
#
# St. Dev. XZ Distance per Jump
# Purist: 2.7533873325606857
# CCO: 2.428489856584749
#
#
# St. Dev. Y Distance per Jump
# Purist: 3.6249744125251167
# CCO: 1.7139230078882934
#
#
# St. Dev. Total Distance per Jump
# Purist: 4.395756973620092
# CCO: 2.6880974762934375
#
#
# St. Dev. Yaw Angle per Jump
# Purist: 0.5470346061627646
# ...

# %%
# Plots (for visualization and the paper)

plt.plot(PuristJumpNum, PuristTime)
plt.title("ToTS Purist Airtime")
plt.xlabel("Jump Number")
plt.ylabel("Airtime (s)")
plt.show()

plt.plot(PuristJumpNum, PuristXZDistance)
plt.plot(PuristJumpNum, PuristYDistance)
plt.plot(PuristJumpNum, PuristTotalDistance)
plt.title("ToTS Purist Distance")
plt.xlabel("Jump Number")
plt.ylabel("XZ Distance (Studs)")
plt.legend(["XZ Distance","Y Distance","Total Distance"])
plt.show()

plt.plot(PuristJumpNum, PuristYawAngle)
plt.plot(PuristJumpNum, PuristPitchAngle)
plt.plot(PuristJumpNum, PuristTotalAngle)
plt.title("ToTS Purist Angle per Jump")
plt.xlabel("Jump Number")
plt.ylabel("Angle (rad)")
plt.legend(["Yaw Angle","Pitch Angle","Total Angle"])
plt.show()

plt.plot(CCOJumpNum, CCOTime)
plt.xlabel("Jump Number")
plt.ylabel("Airtime (s)")
plt.title("ToTS CCO Airtime")
plt.show()

plt.plot(CCOJumpNum, CCOXZDistance)
plt.plot(CCOJumpNum, CCOYDistance)
plt.plot(CCOJumpNum, CCOTotalDistance)
plt.title("ToTS CCO Distance")
plt.xlabel("Jump Number")
plt.ylabel("XZ Distance (Studs)")
plt.legend(["XZ Distance","Y Distance","Total Distance"])
plt.show()

plt.plot(CCOJumpNum, CCOYawAngle)
plt.plot(CCOJumpNum, CCOPitchAngle)
plt.plot(CCOJumpNum, CCOTotalAngle)
plt.title("ToTS Purist Angle per Jump")
plt.xlabel("Jump Number")
plt.ylabel("Angle (rad)")
plt.legend(["Yaw Angle","Pitch Angle","Total Angle"])
plt.show()
